# %%
def introduction():
    print(f'''
        {'*' * 100}
        This is a story about a young adult named Jimmy/Julia who grew up in the rural 
        farmlands in South Africa geographically separated from modern infrastructure.  
        This has limited Jimmy/Julia’s life to a very slow, under-developed 
        perspective on life.  Jimmy/Julia then moves to Joburg and gets the culture 
        shock of a big City. The City Jimmy/Julia has to get to will be 4 hours away if using a motor.
        For more context on the history of the story checkout the reference: 
        https://en.wikipedia.org/wiki/African_Jim
        {'*' * 100}
        ''')
introduction()

# %%
# ##Assigning a character name variable input and calling them to start the game
# def Character_Decision():

#     character_input = input("Choose your character? Please enter Jimmy or Julia \n")
#     print(f'Thanks! Your Character name will be {character_input}, let us play the game!')

#     start_game = input(f'{character_input} press enter to continue')

# %%
#This is the first scene in the game which allows the user to input a prompt 
#& calls the predefined character variable it also creates a while with an if/elseif statement
def Limpopo_Decision():
    Answer_Limpopo = 3
    print(f"{character_input}, you're in Limpopo and you need to get to Joburg before the \
    taxi rank closes at 19:00.")
    print('''Choose your next move:
    A)	Take a taxi to the nearest town for R20.
    B)	Wait an hour to catch the bus to the nearest town for R15.
    C)	Take a walk to the nearest town for 90 minutes and spend R0.
               ''') 
    while Answer_Limpopo > 0:
        action_one = input("Please enter A, B or C then press Enter to continue \n")
        if action_one == "A":
            print(f'You have chosen to take the taxi, let us proceed to the next stage {character_input}, hop on!')
            break
        elif action_one == "B":
            print(f'You have chosen to wait for the bus, well it has arrived. Let us proceed to the next stage {character_input}!')
            break
        elif action_one == "C":
            print(f'You have chosen to take a walk to the nearest town, well let us proceed. Start walking {character_input}!')
            break
        else:
            print(f'You have entered the wrong option, {action_one} is invalid.\
            Please enter A, B or C then press Enter to continue \n')
            Answer_Limpopo -= 1
            
    action_one = Decision_randomizer()
    print(f'We have simulated a random answer for you')
    return action_one

# %%
# #importing the necessary package
import random
def Decision_randomizer():
# # declaring objects
    Answer_number = random.randint(0,2)

    Possible_Answer = ["A", "B", "C"]

    return Possible_Answer[Answer_number]


# Decision_randomizer()

# %%
#This is a fail function for exiting the game due to error or intention
def fail():
    print('You have failed the game :(')
    input('<Game Over>')
    exit(0)

# %%
#This is the second scene in the game which allows the user to input a prompt 
#& calls the predefined character variable it also creates a while with an if/elseif statement
#the last piece of code is a randomizer which executes when the loop breaks after 3 false inputs
def Town_Decision(): 

    Answer_Town = 3
    print(f"Welcome to the second stage {character_input}! You have now arrived in town!")
    print('''Choose your next move:
    A)	Find the taxi rank and walk there.
    B)	Find out which way Joburg is & start hitch-hiking.
    C)	Wait 2 hours for the bus to Joburg
    ''')

    while Answer_Town > 0:
        action_two = input("Please enter A, B or C then press Enter to continue \n")
        if action_two == "A":
            print(f'You have chosen to take a walk to the taxi rank, let us see how that goes {character_input}!')
            return action_two
        elif action_two == "B":
            print(f'You have chosen to start hitch-hiking, hmmm risky! Let us see how that goes {character_input}!')
            return action_two
        elif action_two == "C":
            print(f'You have chosen to wait for the bus, well let us see how that goes {character_input}!')
            return action_two
        else:
            print(f'You have entered the wrong option, {action_two} is invalid \n')
            Answer_Town -= 1
# Town_Decision()

# %%
#This is the third scene in the game which allows the user to input a prompt 
#It calls the predefined character variable 
#it also creates a while loop with an if/elseif statement
#the last piece of code is a randomizer which executes when the loop breaks after 3 false inputs

def Walk_Decision():
    Walk_Answer = 3
    print(f"Okay {character_input},the next decision you make will be critical for your survival in this game, think carefully!")
    print('''Choose your next move:
    A)	You follow a mixed group of people who are also carrying bags and seem like they are walking to the taxi rank
    B)	You take a road that is very quiet with no traffic and you are the only person on the road
    C)	You ask a stranger to walk with you to the taxi rank
    ''')
    while Walk_Answer > 0:
        action_three = input("Please enter A, B or C then press Enter to continue \n")
        if action_three == "A":
            print(f'You have chosen to follow a group of strangers, let us see how that goes {character_input}!')
            return action_three
        elif action_three == "B":
            print(f'You have chosen the road less traveled, hmmm risky! Let us see how that goes {character_input}!')
            return action_three
        elif action_three == "C":
            print(f'You have chosen to talk to strangers, will your Mom be happy? Well let us see how that goes {character_input}!')
            return action_three
        else:
            print(f'You have entered the wrong option, {action_three} is invalid \n')
            Walk_Answer -= 1
            
    action_three = Decision_randomizer()
    print(f'We have simulated a random answer for you')
    return action_three
# Walk_Decision()

# %%
#This is the third scene in the game which allows the user to input a prompt 
#It calls the predefined character variable 
#it also creates a while loop with an if/elseif statement
#the last piece of code is a randomizer which executes when the loop breaks after 3 false inputs
def Hike_Decision():
    Hike_Answer = 3
    print(f"Okay {character_input},the next decision you make will be critical for your survival in this game, think carefully!")
    print('''Choose your next move:
    A)	A truck driver stops for you and he tells you that he is going to Pretoria which is an hour away from Joburg CBD
    B)	An old lady with her 22-year-old son say they can drop you off in Joburg CBD
    C)	A young couple with their toddler is headed to Midrand which is 20 minutes away from Joburg CBD
    ''')
    while Hike_Answer > 0:
        action_three = input("Please enter A, B or C then press Enter to continue \n")
        if action_three == "A":
            print(f'You have chosen to ride with the truck driver, let us see how that goes {character_input}!')
            return action_three
        elif action_three == "B":
            print(f'You have chosen to ride with the old lady, seems innocent enough! Let us see how that goes {character_input}!')
            return action_three
        elif action_three == "C":
            print(f'You have chosen to ride with the young couple, that should be fun! Well let us see how that goes {character_input}!')
            return action_three
        else:
            print(f'You have entered the wrong option, {action_three} is invalid \n')
            Hike_Answer -= 1
            
    action_three = Decision_randomizer()
    print(f'We have simulated a random answer for you')
    return action_three
# Hike_Decision()

# %%
#This is the third scene in the game which allows the user to input a prompt 
#It calls the predefined character variable 
#it also creates a while loop with an if/elseif statement
#the last piece of code is a randomizer which executes when the loop breaks after 3 false inputs
def Bus_Decision():
    Bus_Answer = 3
    print(f"Okay {character_input},the next decision you make will be critical for your survival in this game, think carefully!")
    print('''Choose your next move:
    A)	The bus arrives after two hours but will only arrive in Joburg at 21:00
    B)	After an hour one of the people waiting for the bus convinces a drunk man convinces you that it is quicker to hitch -hike with him
    C)	You fear that the bus will arrive in Joburg too late and regret your decision to leave home too late so you cave into your anxiety
    ''')
    while Bus_Answer > 0:
        action_three = input("Please enter A, B or C then press Enter to continue \n")
        if action_three == "A":
            print(f'You have chosen to wait 2 hours for the bus, let us see how that goes {character_input}!')
            return action_three
        elif action_three == "B":
            print(f'You ditch the bus and follow the drunk man, hmmm risky! Let us see how that goes {character_input}!')
            return action_three
        elif action_three == "C":
            print(f'You have chosen to act out of fear, will this help you win? Well let us see how that goes {character_input}!')
            return action_three
        else:
            print(f'You have entered the wrong option, {action_three} is invalid \n')
            Bus_Answer -= 1
            
    action_three = Decision_randomizer()
    print(f'We have simulated a random answer for you')
    return action_three
# Bus_Decision()

# %%
#This is a function to read the decisions made in level 2 and run an if statement to show results
def Walk_Result(action_three):

    LifeIndicator = input(prompt = "Press enter to find out your fate")

    if action_three == "A":
        print(f"Congrats {character_input}! Following these people from a distance\
        leads you to the taxi rank successfully and you find a taxi that will take you to your Joburg destination")
    if action_three == "B":
        print(f" ABORT MISSION {character_input}! A group of bandits show up surprisingly and rob you along the way - GAME OVER ")
    if action_three == "C":
        print(f" ABORT MISSION {character_input}! The stranger leads you astray and you never find the taxi rank - GAME OVER ")
# Walk_Result()

# %%
#This is a function to read the decisions made in level 2 and run an if statement to show results
def Hike_Result(action_three):
    print(f'{action_three} should work')
    LifeIndicator = input(prompt = "Press enter to find out your fate")
    
    if action_three == "A":
        print(f"Congrats {character_input}! The truck driver gets a call from his\
        boss and to your luck he must deliver his goods in the Joburg CBD 2 blocks away from your destination.")
    if action_three == "B":
        print(f" ABORT MISSION {character_input}!The 22-year-old son pulls out a gun,\robs you of your money, phone and other personal belongings then subsequently kicks you out of their car - GAME OVER ")
    if action_three == "C":
        print(f" ABORT MISSION {character_input}! You start coughing & sneezing prolifically \& the young couple fear you have Covid-19 & might infect them & their toddler so they kick you out of their car after 2 hours - GAME OVER ")
        
    
# Hike_Result()

# %%
#This is a function to read the decisions made in level 2 and run an if statement to show results
def Bus_Result(action_three):

    LifeIndicator = input(prompt = "Press enter to find out your fate")
 
    if action_three == "A":
        print(f"Congrats {character_input}! You take the bus successfully and it leads to the Joburg CBD a 5-minute walk from your destination")
    if action_three == "B":
        print(f" ABORT MISSION {character_input}! You never catch a hike & subsequently miss the bus - GAME OVER ")
    if action_three == "C":
        print(f" ABORT MISSION {character_input}! You walk back home and decide to restart the trip earlier the next day- GAME OVER ")
    
# Bus_Result()

# %%
#Run the decision tree from level 2 & call the functions with the logical decision steps
introduction()

character_input = input("Choose your character? Please enter Jimmy or Julia \n")
print(f'Thanks! Your Character name will be {character_input}, let us play the game!')
start_game = input(f'{character_input} press enter to continue')
    
Limpopo_Decision()
action_two = Town_Decision()
if action_two == "A":
    action_three = Walk_Decision()
    if action_three == "A" or action_three == "B" or action_three == "C":
        Walk_Result(action_three)
elif action_two == "B":
    action_three = Hike_Decision()
    if action_three == "A" or action_three == "B" or action_three == "C":
        Hike_Result(action_three)
elif action_two == "C":
    action_three = Bus_Decision()
    if action_three == "A" or action_three == "B" or action_three == "C":
        Bus_Result(action_three)
else:
    print(f"Sorry {character_input}! It seems something's gone wrong")

fail()
# Out:
#         ****************************************************************************************************
#         This is a story about a young adult named Jimmy/Julia who grew up in the rural
#         farmlands in South Africa geographically separated from modern infrastructure.
#         This has limited Jimmy/Julia’s life to a very slow, under-developed
#         perspective on life.  Jimmy/Julia then moves to Joburg and gets the culture
#         shock of a big City. The City Jimmy/Julia has to get to will be 4 hours away if using a motor.
#         For more context on the history of the story checkout the reference:
#         https://en.wikipedia.org/wiki/African_Jim
#         ****************************************************************************************************
#
# Choose your character? Please enter Jimmy or Julia
#
# Thanks! Your Character name will be , let us play the game!
#  press enter to continue
# ...
